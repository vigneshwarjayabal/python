# %% [markdown]
# <a href="https://colab.research.google.com/github/vigneshwarjayabal/python/blob/main/Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Print() function**
# ![image.png](data:image/png;base64,...)

# %%
print("hello")
print(45)
print(True)
# Out:
# hello
# 45
# True

# %%
print("hello world \n hello world") #\n is used to go to new line and print the content give after it .
# Out:
# hello world
#  hello world

# %% [markdown]
# # **Python Variable,Identifiers and Keywords**
#
# ![image.png](data:image/png;base64,...)

# %%
import keyword
import pprint
pprint.pprint(keyword.kwlist)
print(len(keyword.kwlist))
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']
# 35

# %% [markdown]
# # **Variable Naming:**
# ![image.png](data:image/png;base64,...)

# %%
a = "hello world " # a is labled box and inside box there is a string called "hello world ".

# %% [markdown]
# # **Python Data Types**
# #**1)String**
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
dir(str)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'replace',
# ...

# %%
print("hello how r u ") #string
print('hellow how r u ')
# Out:
# hello how r u
# hellow how r u

# %%
print("hello"[0]) # this will return the element of string in 0 index . we can access the elements of string my mentioning the index .
# Out:
# h

# %%
print("""hello,
how are you ,
how is your day going on """)
# Out:
# hello,
# how are you ,
# how is your day going on

# %%
print("hello,world"[2:5]) # starting index is 2(included):ending index 5(excluded)
# Out:
# llo

# %%
print("hello,world"[:5]) # leaving out starting index then it will take 0 as starting
print("hello,world"[2:]) # leaving out ending index then it will take last index as ending
# Out:
# hello
# llo,world

# %%
print("hello,world"[-7:-1]) # negative index will slice the string from end .
print("hello,world"[:-1])
print("hello,world"[-9:])
# Out:
# o,worl
# hello,worl
# llo,world

# %%
dob = "20/10/2000"
creditcard = "1234 5678 9012 3456"
name = "rajesh kumar"

creditcard[len(creditcard) - 4 : len(creditcard)]
# Out:
# '3456'

# %%
password = name[:4] + dob[len(dob) - 4 : len(dob)] + creditcard[len(creditcard) - 4 : len(creditcard)]
password
# Out:
# 'raje20003456'

# %%
password = name[:4] + dob[len(dob) - 4 : ] + creditcard[len(creditcard) - 4 : ]
password
# Out:
# 'raje20003456'

# %% [markdown]
# # **String Methods part 1:**
# ![image.png](data:image/png;base64,...)

# %%
A = "HELLO WORLD"
B = "hello@world@welcome "
C = "  hello world   "

# %%
print(A.lower())
print(B.upper())
print(C)
print(C.strip())
print(A.replace("O","I"))
print(B.split("@"))
# Out:
# hello world
# HELLO@WORLD@WELCOME
#   hello world
# hello world
# HELLI WIRLD
# ['hello', 'world', 'welcome ']

# %%
name="dinesh kumar"
name.split()
# Out:
# ['dinesh', 'kumar']

# %% [markdown]
# # String Concatenation And f String:
# ![image.png](data:image/png;base64,...)

# %%
A = " welocme"
B = "akaash"
C = A +" "+ B
print(C)
# Out:
#  welocme akaash

# %%
age = 45
txt = f"hi i am john, my age is {age}"
print(txt)
# Out:
# hi i am john, my age is 45

# %%
price = 45
txt = f"price of rice is {price:.2f}" # .2f is two floating point
print(txt)
# Out:
# price of rice is 45.00

# %%
txt = f"price of 5 kg rice is {5*45}" # placeholder can also have operation "maths"
print(txt)
# Out:
# price of 5 kg rice is 225

# %%
print("she said:\"hello\"and turned left") # backslash inserted before and after a character in string . this is called escape characters.
# Out:
# she said:"hello"and turned left

# %% [markdown]
# # **String Methods part 2:**
# ![image.png](data:image/png;base64,...)

# %%
A = " hello welcome to kids show "
B = "vigneshwar"

# %%
print(A.title())
# Out:
#  Hellow Welcome To Kids Show

# %%
print(A.swapcase())
# Out:
#  HELLOW WELCOME TO KIDS SHOW

# %%
print(B.capitalize())
# Out:
# Vigneshwar

# %%
c = "i love dhoni, dhoni is my inspiration,dhoni is great player"
print(c.count("dhoni"))
# Out:
# 3

# %%
print(c.find("l"))
# Out:
# 2

# %%
print(B.center(20))
print(B.center(20,"#"))
# Out:
#      vigneshwar
# #####vigneshwar#####

# %%
print(" ".join(A))
print("".join(A))
print("_".join(A))
# Out:
#   h e l l o   w e l c o m e   t o   k i d s   s h o w
#  hello welcome to kids show
#  _h_e_l_l_o_ _w_e_l_c_o_m_e_ _t_o_ _k_i_d_s_ _s_h_o_w_

# %% [markdown]
# # Interger in Python
# ![image.png](data:image/png;base64,...)

# %%
a = 12
b = 234567
c = -123

print(a,b,c)
# Out:
# 12 234567 -123

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
e = 12.23
d = -23.45
f = 34j
t = -5j

print(d,e,f,t)
print(type(e))
print(type(f))
# Out:
# -23.45 12.23 34j (-0-5j)
# <class 'float'>
# <class 'complex'>

# %% [markdown]
# # Boolean:
#
# ![image.png](data:image/png;base64,...)

# %%
print(10 > 9)
print(10 == 9)
print(10 < 9)
# Out:
# True
# False
# False

# %%
a = 200
b = 100

if b > a: # if this condition is true it will print the first print statement, if it is false it will print statement in esle part .
  print("b is greater than a ")
else:
  print("a is greater than b ")
# Out:
# a is greater than b

# %% [markdown]
# # Python input function:
#
# ![image.png](data:image/png;base64,...)

# %%
name = input("what is your name ")
age = int(input("what is your age"))

a = (f"hello, i am  {name} and my age is {age}")
b = ("hello"+" " + name)

print(a)
print(b)
# Out:
# what is your name vigneshwar
# what is your age27
# hello, i am  vigneshwar and my age is 27
# hello vigneshwar

# %% [markdown]
# # len() Fucntion:
# # it is used find the lenght of the string or word

# %%
print(len(A))
# print(len(123)) # TYPE ERROR lenght fuction cant aplied for int
# print(name+age) # TYPE ERROR  we cant combine string and integer using string concatenation.
# Out:
# 28

# %% [markdown]
# # Simple Formating The String Without Using F String:

# %%
name = input("enter your name ")
city = input("enter your city ")
salary = float(input("enter your salary "))
age = int(input("enter your age "))

message = "hello my name is {} and i live in {} and my salary is {} and my age is {}" # simple format string without using f string
message.format(name,city,salary,age)
# Out:
# enter your name vicky
# enter your city trichy
# enter your salary 45000
# enter your age 27
# 'hello my name is vicky and i live in trichy and my salary is 45000.0 and my age is 27'

# %%
name = input("enter your name ")
city = input("enter your city ")
salary = float(input("enter your salary "))
age = int(input("enter your age "))

message = "hello my name is {0} and i live in {2} and my salary is {3} and my age is {1}" # simple format string without using f string
message.format(name,age,city,salary)
# Out:
# enter your name akaash
# enter your city coimbatore
# enter your salary 45880
# enter your age 21
# 'hello my name is akaash and i live in coimbatore and my salary is 45880.0 and my age is 21'

# %% [markdown]
# # Type Conversion
# # You can convert from one data type to another data type  with the int(), float(), and complex() methods.

# %%
# int ---> float,str and complex:
a = 12
print(float(a))
print(complex(a))
print(str(a))
# Out:
# 12.0
# (12+0j)
# 12

# %%
# float --> int , complex,string
b = 12.34
print(int(b))
print(complex(b))
print(str(b))
# Out:
# 12
# (12.34+0j)
# 12.34

# %%
#complex --> int and float
c = 34+5j
print(int(c.real))
print(float(c.real))
print(str(c))
# Out:
# 34
# 34.0
# (34+5j)

# %%
#string --> int float
num = "123" #anything inside double or single quotes is string .if a given string are number we can convert into int or float otherwise error will occure.
print(int(num))
print(float(num))
# Out:
# 123
# 123.0

# %%
name = "janani"
print(int(len(name)))
print(float(len(name)))
# Out:
# 6
# 6.0

# %%
a =100
b= 12
print(str(a)+str(b))# converting int --> str and doing concatenation
# Out:
# 10012

# %%
num = "123"  #converting str--> float and doing add operation
name = int(num)
print(10 + name)
# Out:
# 133

# %% [markdown]
# # Mathematical Operation in Python:
#
# # This are used to perform mathematical operations like add, sub,multiply, division etc
#
# # "+" --> addition : add two or more integer.
#
# # "-" --> subtraction : sub two or more integer.
#
# # "*" --> multiplication : multiply two or more integer.
#
# # / --> division : divide two or more integer and return result with decimal.
#
# # // --> floor division: divide two or more integer and return result without decimal.
#
# # % --> modules : which will return the reminder.
#
# # "**" --> power

# %%
print(3+4)
print(10-2)
print(3*2)
print(12/2)
print(12//2)
print(13%2)
print(3**3)
# Out:
# 7
# 8
# 6
# 6.0
# 6
# 1
# 27

# %% [markdown]
# # Precedence and Associativity in python:
#
# PEMDAS
#
# Paranthesis-() - L to R associativity
#
# exponent "**" - R to L associativity
#
# multiply "*" - L to R associativity
#
# division / - L to R associativity
#
# addition "+" - L to R associativity
#
# subtraction "-" L to R associativity

# %%
a = (3*3+3/3-3)
b = (3*(3+3)/3-3)

# %%
print(a,b)
# Out:
# 7.0 3.0

# %% [markdown]
# ![pa.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # Python Assignment Operation:
#
# Assignment operators are used to assign values to variables.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Python Comparison Operators:
#
# Comparison operators are used to compare two values.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Python Logical Operators:
#
# Logical operators are used to combine conditional statements.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Python Identity Operators:
#
# Identity operators are used to compare the objects, not if they are equal, but if they are actually the same object, with the same memory location.
#
# ![image.png](data:image/png;base64,...)

# %%
x = [1,2,3,4]
y = [5,6,7,8]
z = x

print(z is x)
print(z is y )

print(x is not y)
print(x is not z)

print(x==y)
print(x==z)
# Out:
# True
# False
# True
# False
# False
# True

# %% [markdown]
# # Python Membership Operators:
#
# Membership operators are used to test if a sequence is presented in an object.
#
# ![image.png](data:image/png;base64,...)

# %%
# Using List:

fruits = ["apple", "banana", "cherry"]


print("apple" in fruits)
print("grape" in fruits)


print("grape" not in fruits)
print("banana" not in fruits)
# Out:
# True
# False
# True
# False

# %%
# Using a String:
text = "Hello, Python!"

print("Python" in text)
print("java" in text)
print("Python" not in text)
print("Java" not in text)
# Out:
# True
# False
# False
# True

# %%
# Using a dictionary (checks keys)
info = {"name": "Alice", "age": 25}

print("name" in info)
print("Alice" in info)
print(25 not in info)
# Out:
# True
# False
# True

# %% [markdown]
# # Python Bitwise Operators:
#
# Bitwise operators are used to compare (binary) numbers.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Conditional Statement:
#
# 1) if else conditional statement:
#
# Syntax:
#
# ![image.png](data:image/png;base64,...)

# %%
water_level = int(input("enter the water level:"))
if water_level > 80:
  print("Drain Water")
else:
  print("Continue")
# Out:
# enter the water level:90
# Drain Water

# %%
# Code to purchase a ticket for rollercoaster
# condition: person height should be > 120cm

print("Welcome To Vignesh Theame Park")

height = int(input("enter your height:"))

if height > 120:
  print("your eligible to ride in RollerCoaster")
else:
  print("your not eligible to ride in RollerCoaster")
# Out:
# Welcome To Vignesh Theame Park
# enter your height:130
# your eligible to ride in RollerCoaster

# %%
# Code to find the given number is Odd or Even

number = int(input("enter the number:"))

if number % 2  == 0:
  print("Even")
else:
  print("Odd")
# Out:
# enter the number:13
# Odd

# %% [markdown]
# 2) Nested if else Statement:
#
# You can have if statements inside if statements, this is called nested if statements.
#
# Syntax:
#
# ![image.png](data:image/png;base64,...)

# %%
# continue code of roller coaster ticket
#1 hight > 120cm
#2 age <= 18 --> 7$ else age > 18 -->12$

print("Welcome to Vignesh Theame Park")
height = int(input("enter your height"))

if height > 120:
  print("your eligible to ride")
  age = int(input("enter your age:"))
  if age <= 18:
    print("your ticket price is 7$")
  else:
    print("your ticket price is 12$")
else:
  print("your not eligible to ride")
# Out:
# Welcome to Vignesh Theame Park
# enter your height130
# your eligible to ride
# enter your age:17
# your ticket price is 7$

# %% [markdown]
# 3) elif statement:
#
# Syntax:
#
# ![image.png](data:image/png;base64,...)

# %%
# continue code of roller coaster ticket
#1 hight > 120cm
#2 age <= 12 --> 5$ age 12-18 -->7$  age > 18 -->12$

print("Welcome to Vignesh Theame Park")
height = int(input("enter your height"))

if height > 120:
  print("your eligible to ride")
  age = int(input("enter your age:"))
  if age < 12:
    print("your ticket price is 5$")
  elif age > 12 and age < 18:
    print ("your ticket price is 7$")
  else:
    print("your ticket price is 12$")
else:
  print("your not eligible to ride")
# Out:
# Welcome to Vignesh Theame Park
# enter your height123
# your eligible to ride
# enter your age:13
# your ticket price is 7$

# %%
# Code to find the BMI based on user's weight and heigth.
# BMI = weight/(height*height)

h = int(input("enter your height:")) / 100
w = int(input("enter your weight"))


bmi = w / (h*h)

if bmi < 18.5:
  print(f"your BMI is {bmi} and your are UnderWeight")
elif bmi >=18.5 and bmi < 25:
  print(f"your BMI is {bmi} and your are Normal")
elif bmi >=25 and bmi < 30:
  print(f"your BMI is {bmi} and your are Slight OverWeight")
elif bmi >= 30 and bmi < 35:
  print(f"your BMI is {bmi} and your are Obese")
else:
  print(f"your BMI is {bmi} and your are clinicall Obese")
# Out:
# enter your height:160
# enter your weight60
# your BMI is 23.437499999999996 and your are Normal

# %%
# write a code to find the given year is either leap year or not

year = int(input("enter the year"))

if year % 4 == 0:
  if year % 100 == 0:
    if year % 400 == 0:
      print("It is a leap year")
    else:
      print("it is not a leap year")
  else:
    print("it is a leap year")
else:
  print("it is not a leap year")
# Out:
# enter the year2014
# it is not a leap year

# %% [markdown]
# **Write a program to build an automatic pizza bill. Based on user's order , work out the final bill:**
#
# small pizza : $15
#
# medium pizza : $20
#
# big pizza : $25
#
# add pepperoni:
#
# small:+ $2
#
# other :+ $3
#
# extra cheese:
#
# all size: + $1

# %%
print("Thanks For Chossing Vicky Pizza Delivery!!!")
size = input("Please Chosse the Size of the Pizza do you want? S or M or L")
add_pepperoni = input("Do you want pepperoni? Y or N")
extra_chesse = input("Do you want extra chesse? Y or N")

bill = 0

if size == "S":
  bill += 15
elif size == "M":
  bill += 20
else:
  bill += 25

if add_pepperoni == "Y" :
  if size == "S":
    bill += 2
  else:
    bill += 3

if extra_chesse == "Y":
  bill += 1

print(f"Your Final bill is {bill}")
# Out:
# Thanks For Chossing Vicky Pizza Delivery!!!
# Please Chosse the Size of the Pizza do you want? S or M or LM
# Do you want pepperoni? Y or NN
# Do you want extra chesse? Y or NY
# Your Final bill is 21

# %% [markdown]
# #**Randomization in Python:**
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
import random

a = random.randint(1,10) # returns a random number between the given range.
print(a)
# Out:
# 8

# %%
b = random.random() # returns a random float number between 0 and 1
print(b)
# Out:
# 0.25374317788865675

# %%
c = random.getrandbits(12) # retrns a number representing the random bits.
print(c)
# Out:
# 2317

# %%
random.seed(3) # initalize the random number generator.
state = random.getstate()  # return the current internal state of the random number generator.
print("Generate random sequence of 3 integer...")
for i in range(3):
  print(random.randint(1,1000))

random.setstate(state) # restores the internal state of the random number generator.

print("Generate random sequence of 3 integer...")
for i in range(3):
  print(random.randint(1,1000))
# Out:
# Generate random sequence of 3 integer...
# 244
# 607
# 558
# Generate random sequence of 3 integer...
# 244
# 607
# 558

# %%
i = 10
j = 100

d = random.randrange(i,j) # returns a randomly selected integer from range(Start,end)
print(d)
# Out:
# 39

# %%
apple = [random.randint(0,i) for i in range(10)]
print(apple)
# Out:
# [0, 1, 2, 3, 3, 5, 6, 2, 3, 2]

# %%
random.shuffle(apple) # takes a sequence and returns the sequence in a random order.
print(apple)
# Out:
# [0, 2, 6, 2, 5, 1, 3, 2, 3, 3]

# %%
for i in range(5):
  print(random.choice(apple)) # returns a random selected item from the given sequence.
# Out:
# 1
# 0
# 5
# 3
# 6

# %%
for i in range(5):
  print(random.sample(apple,1)) #Returns a random sample from a sequence of length k.
# Out:
# [0]
# [5]
# [3]
# [3]
# [2]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import random

i = 0
j = 1

a = random.randint(i,j)
print(a)

if a == 1:
  print("Heads")
else:
  print("Tails")
# Out:
# 1
# Heads

# %% [markdown]
# #**Python Lists:**
# ![image.png](data:image/png;base64,...)

# %%
roll_no = [101,102,103,104,105] # list which contain int datatype.
names = ["akaash","vignesh","chithra","jayabal"] # list which contain string datatype.
mix_list = [102,"vignesh",True,10.10] # list which contain mixed datatype like int,str,boolean,float.

print(roll_no)
print(names)
print(mix_list)
# Out:
# [101, 102, 103, 104, 105]
# ['akaash', 'vignesh', 'chithra', 'jayabal']
# [102, 'vignesh', True, 10.1]

# %%
friuts = list(("apple","banana","mango","graphs")) # It is also possible to use the list() constructor when creating a new list.
print(friuts)
# Out:
# ['apple', 'banana', 'mango', 'graphs']

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print(len(friuts)) # we can use len() function to determine how many no of item present in a list
# Out:
# 4

# %%
print(type(friuts)) # From Python's perspective, lists are defined as objects with the data type 'list':
# Out:
# <class 'list'>

# %%
print(friuts[0]) # will print item in the list friuts at index 0
# Out:
# apple

# %%
print(friuts[3])# will print item in the list friuts at index 3
# Out:
# graphs

# %%
print(friuts[-1]) # i can also acces the last position of list using negative index.
# Out:
# graphs

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print(friuts[1:3])#It will start at starting index (include) and stop before the end index(not include).
print(friuts[:3])#when starting index is not given it will take 0 as starting index.
print(friuts[2:])#when ending index is not given it will take last position of elemnet in list as ending index.
# Out:
# ['banana', 'mango']
# ['apple', 'banana', 'mango']
# ['mango', 'graphs']

# %%
print(friuts[0:3:2]) # 2 is the step sequence by default step sequence is 1.
# Out:
# ['apple', 'mango']

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
l1 = ["sachin","gambhir","dravid","srikant"]
l1[1] = "shewag"
print(l1)
# Out:
# ['sachin', 'shewag', 'dravid', 'srikant']

# %%
l1[1:3] = ["dhoni","virat"]
l1
# Out:
# ['sachin', 'dhoni', 'virat', 'srikant']

# %%
l1.insert(2,"shewag")
l1
# Out:
# ['sachin', 'dhoni', 'shewag', 'virat', 'srikant']

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
l1.append("rohit")
l1
# Out:
# ['sachin', 'dhoni', 'shewag', 'virat', 'srikant', 'rohit']

# %%
l2 = ["pant","pandia","ruturaj"]
l1.extend(l2)
l1
# Out:
# ['sachin',
#  'dhoni',
#  'shewag',
#  'virat',
#  'srikant',
#  'rohit',
#  'pant',
#  'pandia',
#  'ruturaj']

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
l1 = ["sachin","gambhir","dravid","srikant"]

# %%
l1.remove("sachin")
print(l1)
# Out:
# ['gambhir', 'dravid', 'srikant']

# %%
l1 = ["sachin","gambhir","dravid","srikant","dravid"]
l1.remove("dravid")
l1
# Out:
# ['sachin', 'gambhir', 'srikant', 'dravid']

# %%
l1 = ["sachin","gambhir","dravid","srikant","dravid"]
l1.pop(3)
l1
# Out:
# ['sachin', 'gambhir', 'dravid', 'dravid']

# %%
l1 = ["sachin","gambhir","dravid","srikant","dravid"]
l1.pop()
l1
# Out:
# ['sachin', 'gambhir', 'dravid', 'srikant']

# %%
l1 = ["sachin","gambhir","dravid","srikant","dravid"]
del l1[4]
l1
# Out:
# ['sachin', 'gambhir', 'dravid', 'srikant']

# %%
l1 = ["sachin","gambhir","dravid","srikant","dravid"]
del l1

# %%
l1 = ["sachin","gambhir","dravid","srikant","dravid"]
l1.clear()

# %%
l1
# Out:
# []

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import random

names = input().split(",") # this is used to get items of list from the user while running the code.
a = len(names)
random_choice = random.randint(0,a-1)
print(names[random_choice])
# Out:
# rahul,vicky,sanjay,saran,akaash,praveen
# praveen

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
list1 = [1,2,3,4]
print(list1[4])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-16-35d5f5b3829b> in <cell line: 2>()
#       1 list1 = [1,2,3,4]
# ----> 2 print(list1[4])
#
# IndexError: list index out of range

# %%
list1 = [1,2,3,4]
for i in range(len(list1)):
  print(list1[i])
# Out:
# 1
# 2
# 3
# 4

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![memory allocation of nested list.jpg](data:image/jpeg;base64,...)

# %%
number = [1,10,15,[5,2,10],20,-10,15]

# %%
a = number[3][0]
a
# Out:
# 5

# %%
name = ["vicky","akaash",["sanjay","saran"],["praveen","muthu"],"vishal","tharshika"]

# %%
b = name[2][1]
b
# Out:
# 'saran'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
phone = ["apple","samsaung","redmi","poco","oneplus","realme","motorola","nokia"]

# %%
# for loop
# syntax : for item in list of item:
                 # Do something for each item

for i in phone:
  print(i)
# Out:
# apple
# samsaung
# redmi
# poco
# oneplus
# realme
# motorola
# nokia

# %%
# Through index number using range() and len() method.

for i in range(len(phone)):
  print(phone[i] + " " + "phone")
# Out:
# apple phone
# samsaung phone
# redmi phone
# poco phone
# oneplus phone
# realme phone
# motorola phone
# nokia phone

# %%
# while loop

i = 0
while i < len(phone):
  print(phone[i])
  i = i+1
# Out:
# apple
# samsaung
# redmi
# poco
# oneplus
# realme
# motorola
# nokia

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
stut_height = input().split()

for
