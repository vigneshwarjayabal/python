# %% [markdown]
# <a href="https://colab.research.google.com/github/vigneshwarjayabal/python/blob/main/Python2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Python Functions:**
#
# ![image.png](data:image/png;base64,...)

# %%
def message(): # Creating a function.
  name = input("please enter your name :")
  print(f"hello {name} have a nice day !")

# %%
message() # Calling a function.
# Out:
# please enter your name :vigneshwar
# hello vigneshwar have a nice day !

# %%
def invite(fname): # creating a function with single arugument.
  print("hello "+ fname + " " + "have a nice day !")

invite("vicky") # calling a function with input to the arugument.
invite("akaash")
invite("saran")
# Out:
# hello vicky have a nice day !
# hello akaash have a nice day !
# hello saran have a nice day !

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# basic syntax for creating function
# def function name ():
#       do this
#       do this

# basic syntax for function call.
# function name()

# %%
def func3(a,b):   # function with input
  print("A is :",a)
  print("B is :",b)

func3(98,45)
# Out:
# A is : 98
# B is : 45

# %%
x = int(input())
y = int(input())

func3(x,y)
func3(y,x)
# Out:
# 123
# 4
# A is : 123
# B is : 4
# A is : 4
# B is : 123

# %%
def add(a,b): # function with output.
  return a+b

result = add(123,3)
print(result)
# Out:
# 126

# %%
def loan(cibil):  # function with multiple return
  if cibil >= 700:
    return "Eligible"
  else:
    return "Not Eligible"

# %%
data = loan(750)
data
# Out:
# 'Eligible'

# %%
data = loan(695)
data
# Out:
# 'Not Eligible'

# %%
def peanut_bite():
    data = int(input("enter data "))
    return data*0.02
def peanut_sale():
    data = int(input("enter data "))
    return data

# %%
data = peanut_bite()
# Out:
# enter data 10

# %%
data
# Out:
# 0.2

# %%
data = peanut_sale()
data
# Out:
# enter data 10
# 10

# %%
def peanut_bite(qty):
    return qty*0.02
def peanut_sale(qty):
    return qty

# %%
data = peanut_bite(qty=int(input()))
data
# Out:
# 25
# 0.5

# %%
def func3(a,b,c,d):
  return a-b-c-d

# %%
func3(a=30,b=20,c=5,d=1)
# Out:
# 4

# %%
def func4(a,b,c,d): #function with multiple value in a return. the result will be in tuple.
   return a+b,b+c,a+d,b+c-d

# %%
func4(a=30,b=20,c=5,d=1)
# Out:
# (50, 25, 31, 24)

# %%
#function with default arguments

def func(country="India"):
    print("Hi I am from ",country)

# %%
func()
# Out:
# Hi I am from  India

# %%
#Arbitrary Arguments
def sample(*x):   # If you do not know how many arguments that will be passed into your function, add a * before the parameter name in the function definition.
    print(x,type(x))

# %%
sample(100,101,102,103,104,105,106,107,108,109,110,"good")
# Out:
# (100, 101, 102, 103, 104, 105, 106, 107, 108, 109, 110, 'good') <class 'tuple'>

# %%
# Using Arbitary Argument in positional argument
def test(a,*b,c="good"):
    print("a is ",a) # a will be assigned to value 1
    print("b is ",b) # b will be assigned to value 2,3,4,5 because it has * infront of it which is Arbitary Argument.
    print("c is ",c) # c is already assigned a string "good" , now it will replace integer 45.


test(1,2,3,4,5,c=45)
# Out:
# a is  1
# b is  (2, 3, 4, 5)
# c is  45

# %%
def test(a,c="good"):
    print("a is ",a) # a will be assigned to value 1
    print("c is ",c)# # c is already assigned a string "good" , now it will replace integer 400.

test(1,400)
# Out:
# a is  1
# c is  400

# %%
def test(a,c="good",*b):
    print("a is ",a)
    print("b is ",b)
    print("c is ",c)

test(1,2,3,4,5)
# Out:
# a is  1
# b is  (3, 4, 5)
# c is  2

# %%
# dont do this
# because a is aribitary argument so it will take some vaule, c is already assigned to a string, but for b you should put the b variable = and enter value
# so that value will be assinge to b . this is avoid error

#def test(*a,b,c="good"):
#    print("a is ",a)
#    print("b is ",b)
#    print("c is ",c)

# test(1,2,3,4,5)

# %%
def test(*a,b,c="good"):
  print("a is ",a)
  print("b is ",b)
  print("c is ",c)


test(1,2,3,4,5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-0a41d2a36b7f> in <cell line: 7>()
#       5
#       6
# ----> 7 test(1,2,3,4,5)
#
# TypeError: test() missing 1 required keyword-only argument: 'b'

# %%
def test(*a,b,c="good"):
  print("a is ",a)
  print("b is ",b)
  print("c is ",c)


test(1,2,3,4,b=5)
# Out:
# a is  (1, 2, 3, 4)
# b is  5
# c is  good

# %%
# def test(a,b,*d=(6,7),c="good"): #donts because this is invalid syntax.
#     print("a is ",a)
#     print("b is ",b)
#     print("c is ",c)

# %%
# Keyword Arguments
# You can also send arguments with the key = value syntax.
def add(a,b,c):
  d = a + b
  e = b + c
  f  = c + a
  sum = d + e + f
  return d,e,f,sum

add(a=1,b=20,c=100)
# Out:
# (21, 120, 101, 242)

# %%
# this is Arbitrary Keyword Arguments
# If you do not know how many keyword arguments that will be passed into your function, add two asterisk: ** before the parameter name in the function definition.
# result will be dictionary form .
def sample(**x):
    print(x,type(x))

sample(m=23,n=34,p=45)
# Out:
# {'m': 23, 'n': 34, 'p': 45} <class 'dict'>

# %%
def test(a,*b,c="good",**d):
    print("a is ",a)
    print("b is ",b)
    print("d is ",d)
    print("c is ",c)

test(101,102,103,104,x=20,y=45)
# Out:
# a is  101
# b is  (102, 103, 104)
# d is  {'x': 20, 'y': 45}
# c is  good

# %%
test(400,jack=100,jill=200)
# Out:
# a is  400
# b is  ()
# d is  {'jack': 100, 'jill': 200}
# c is  good

# %%
test(400,jack=100,c="swiggy",jill=200)
# Out:
# a is  400
# b is  ()
# d is  {'jack': 100, 'jill': 200}
# c is  swiggy

# %%
# You can send any data types of argument to a function (string, number, list, dictionary etc.),
# and it will be treated as the same data type inside the function.

def test(a,*b,c="good",**d):
    print("a is ",a)
    print("b is ",b)
    print("d is ",d)
    print("c is ",c)

test(45,[65,89],[56,23],(9,100),boy="biggy",girl="barbie")
# Out:
# a is  45
# b is  ([65, 89], [56, 23], (9, 100))
# d is  {'boy': 'biggy', 'girl': 'barbie'}
# c is  good

# %%
# function definitions cannot be empty,
# but if you for some reason have a function definition with no content, put in the pass statement to avoid getting an error.

def add():
  pass

# %%
# You can specify that a function can have ONLY positional arguments, or ONLY keyword arguments.
# To specify that a function can have only positional arguments, add , / after the arguments.

def add(a,b,c,/):
  sum = a + b + c
  return sum

add(10,20,30)
# Out:
# 60

# %%
add(10,20,c=100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-667af3d1e158> in <cell line: 1>()
# ----> 1 add(10,20,c=100)
#
# TypeError: add() got some positional-only arguments passed as keyword arguments: 'c'

# %%
# Without the , / you are actually allowed to use keyword arguments even if the function expects positional arguments
# But when adding the , / you will get an error if you try to send a keyword argument.

# To specify that a function can have only keyword arguments, add *, before the arguments.
#Without the *, you are allowed to use positionale arguments even if the function expects keyword arguments
# But with the *, you will get an error if you try to send a positional argument.

def add(*,a,b,c):
  sum = a + b + c
  return sum

add(a=100,b=200,c=10)
# Out:
# 310

# %%
add(100,b=20,c=100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-42709cb8c702> in <cell line: 1>()
# ----> 1 add(100,b=20,c=100)
#
# TypeError: add() takes 0 positional arguments but 1 positional argument (and 2 keyword-only arguments) were given

# %%
#You can combine the two argument types in the same function.
#Any argument before the / , are positional-only, and any argument after the *, are keyword-only.

def my_function(a, b, /, *, c, d):
  print(a + b + c + d)

my_function(5, 6, c = 7, d = 8)
# Out:
# 26

# %% [markdown]
# #**Recursion in python:**
#
# ![image.png](data:image/png;base64,...)

# %%
# example 1
'''The factorial function:
The factorial of a non-negative integer (n) = the product of all positive integer less than or equal to n
It is often denoted as n!
0! = 1 base case
n! = (n * (n-1))! recursive case '''

def factorial(n): #1
  if n == 0: #2
    return 1 #3
  else: #4
    return n * factorial(n-1) # 5

''' line 2 and 3 are base case and line 5 is recursive case'''
print(factorial(6))
# Out:
# 720

# %%
# example 2
''' The fibonacci sequence
It is a another classical example for recursion.
each number in the sequence is the sum of the two prceeding ones,it usually starting with 0 and 1
fib(0) = 0
fib(1) = 1 this two is base case
fib(n) = fib(n-1)+fib(n-2)for n>1 this is recursive case '''

def fib(n):
  if n == 0:
    return 0
  elif n == 1:
    return 1
  else:
    return fib(n-1) + fib(n-2)

print(fib(6))
# Out:
# 8

# %%
''' sample code for how to get input for dictionary from the user '''

n = int(input())
student = {}
for _ in range(n):
  line = input().split()
  name = line[0]
  marks = list(map(float,line[1:]))
  student[name] = marks

print(student)
# Out:
# 6
# vicky 76
# akaash 74
# gokul 56
# chithra 98
# praveen 45
# balaji 34
# {'vicky': [76.0], 'akaash': [74.0], 'gokul': [56.0], 'chithra': [98.0], 'praveen': [45.0], 'balaji': [34.0]}

# %%
''' sample code for how to get input from the user and store in nested list '''
n = int(input())
student = []
for _ in range(n):
  name = input()
  score = float(input())
  student.append([name,score])
print(student)
# Out:
# 5
# vicky
# 76.55
# chithra
# 98.98
# jayabal
# 97.98
# akaash
# 74.98
# monika
# 65.54
# [['vicky', 76.55], ['chithra', 98.98], ['jayabal', 97.98], ['akaash', 74.98], ['monika', 65.54]]

# %%
print(student[2][1])
# Out:
# 97.98

# %% [markdown]
# #**Lambda, Map, Filter, Zip function:**
#
#
# ![image.png](data:image/png;base64,...)

# %%
# lambda function
# Syntax
# lambda arugments : expressions.

# %%
# one arugments:
cube = lambda x:x*x*x
print(cube(3))
# Out:
# 27

# %%
# multiple arugments:

add = lambda x,y : x + y
print(add(3,4))
# Out:
# 7

# %%
bad = lambda *x:sum(x)
print(bad(12,23,100,23,200,34,76,75))
# Out:
# 543

# %%
good = lambda **a:sum(a.values())
print(good(a=12,b=200,c=300,d=56))
# Out:
# 568

# %%
task = lambda a,b:(a+b,a-b,a*b,a/b)
print(task(72,2))
# Out:
# (74, 70, 144, 36.0)

# %%
''' Map Function :
  Syntax:
  map(function,iterable)
  fucntion is that you want to apply to each item of the iterable, it can be built-in ,lambda function or any other callable object that accepts
  one or more arugment.
  iterable : list,tuple,dict,set'''
# Out:
# ' Map Function :\n  Syntax:\n  map(function,iterable)\n  fucntion is that you want to apply to each item of the iterable, it can be built-in ,lambda function or any other callable object that accepts \n  one or more arugment.\n  iterable : list,tuple,dict,set'

# %%
def square(x):
  return x**2
number = [1,2,3,4,5,6,7]
squars = map(square,number)
print(list(squars))
# Out:
# [1, 4, 9, 16, 25, 36, 49]

# %%
number = [2,4,6,8,10,12,14]
squares = map(lambda x: x**2, number)
print(list(squares))
# Out:
# [4, 16, 36, 64, 100, 144, 196]

# %%
words = ["apple","mango","pineapple"]
lengths = map(len,words)
print(list(lengths))
# Out:
# [5, 5, 9]

# %%
''' Filter Function in python :
Syntax:
filter(function , iterable) '''

age = [45,65,23,78,64,12,0,-12,-13]

def is_even(n):
    return n%2==0

output = filter(is_even,age)
print(output)

# %%
result = list(output)
print(result)
# Out:
# [78, 64, 12, 0, -12]

# %%
verify = list(filter(lambda n:n%2==0,age))
verify
# Out:
# [78, 64, 12, 0, -12]

# %%
emp = {"chithra":26,"jayabal":21,"vigneshwar":34,"akaash":27,"monika":32}

resutl = dict(filter(lambda n:n[1]>25,emp.items())).keys()

# %%
resutl
# Out:
# dict_keys(['chithra', 'vigneshwar', 'akaash', 'monika'])

# %%
result1 = dict(filter(lambda n:n[1]>25,emp.items()))

# %%
result1
# Out:
# {'chithra': 26, 'vigneshwar': 34, 'akaash': 27, 'monika': 32}

# %%
result2 = dict(filter(lambda n:n[1]>25,emp.items())).values()

# %%
result2
# Out:
# dict_values([26, 34, 27, 32])

# %%
list1 = [x[0] for x in list(filter(lambda n:n[1]>25,emp.items()))]
list1
# Out:
# ['chithra', 'vigneshwar', 'akaash', 'monika']

# %%
age
# Out:
# [45, 65, 23, 78, 64, 12, 0, -12, -13]

# %%
data = []
for i in age:
  if i>20:
    data.append(i)
data
# Out:
# [45, 65, 23, 78, 64]

# %%
data = [i for i in age if i>20]

# %%
data
# Out:
# [45, 65, 23, 78, 64]

# %%
''' Zip function in python :
Syntax:
zip(arugments,arugments)'''


a = ("John", "Charles", "Mike")
b = ("Jenny", "Christy", "Monica")

x = zip(a, b)
x

# %%
result = tuple(x)

# %%
result
# Out:
# (('John', 'Jenny'), ('Charles', 'Christy'), ('Mike', 'Monica'))

# %%
# spliting a string : output will be a list of seperated string.
a = "this is a string "
a = a.split()
print(a)
# Out:
# ['this', 'is', 'a', 'string']

# %% [markdown]
# #**Text Alignment:**

# %%
'''In Pyhton , a string of text can be aligned left,right and center. '''
a = "i love you "
a.ljust(2) # left alignment
# Out:
# 'i love you '

# %%
a.rjust(25) # right alignment
# Out:
# '              i love you '

# %%
a.center(25) # center alignment
# Out:
# '       i love you        '

# %% [markdown]
# #**Text Wrap:**

# %%
''' The textwrap module provides two covenient function:
1) wrap(): the wrap function wraps a single paragraph in to a text(string),return as a lsit
2) fill(): the fill() function wraps a single paragraph in text and return a single string contain the wraped paragraph.'''

import textwrap

string = "i am vigneshwar from trichy completed pg degree searching for a job and i love to play cricket"
print(textwrap.wrap(string,10))
# Out:
# ['i am', 'vigneshwar', 'from', 'trichy', 'completed', 'pg degree', 'searching', 'for a job', 'and i love', 'to play', 'cricket']

# %%
print(textwrap.fill(string,10))
# Out:
# i am
# vigneshwar
# from
# trichy
# completed
# pg degree
# searching
# for a job
# and i love
# to play
# cricket

# %%
# covert number into binary:
number = 23
print(bin(number))
# Out:
# 0b10111

# %%
print(oct(number)) # number into octal
# Out:
# 0o27

# %% [markdown]
# # **Python File Handling**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#file operations
#text file
#mode x => create empty file, if file exists then error
#mode r => read
#mode w => write , if file exists then previous content is deleted and new content is added(overwritten)
                    #if file dosn't exist then new file is created then content is added
#mode a => append , if file exists then previous content is not deleted and new content is added at end
                    #if file dosn't exist then new file is created then content is added

# %%
# #basix syntax
# ''' file = open('filename','mode')
#     file.close() '''

# ''' with open('filename','mode') as file
# using with statement to open a file will enusre that file is properly closed after process complete.'''

# %%
file = open('example.txt','x') # x mode will create a new file .

# %%
file = open('example.txt','w') # w mode is to write content into the file
file.write('welcome to tutorial documnet\n')
file.write('this is a testing document')
file.close()

# %%
file = open('example.txt','r')
content = file.read()
print(content)
file.close
# Out:
# welcome to tutorial documnet
# this is a testing document
# <function TextIOWrapper.close()>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
file = open('example.txt','r')
content = file.read()
print(content)
file.close
# Out:
# welcome to tutorial documnet
# this is a testing document
# <function TextIOWrapper.close()>

# %%
file = open('/content/example.txt','r')
content = file.read()
print(content)
file.close
# Out:
# welcome to tutorial documnet
# this is a testing document
# <function TextIOWrapper.close()>

# %%
file = open('example.txt','r')
content = file.read(7)
print(content)
file.close
# Out:
# welcome
# <function TextIOWrapper.close()>

# %%
file = open('example.txt','r')
content = file.readline()
print(content)
file.close
# Out:
# welcome to tutorial documnet
# <function TextIOWrapper.close()>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
file = open('example.txt','a')
file.write('testing is going super\n')
file.write('progress is to good\n')
file.close()

# %%
file = open('example.txt','r')
print(file.read())
file.close()
# Out:
# welcome to tutorial documnet
# this is a testing documenttesting is going superprogress is to goodtesting is going superprogress is to goodtesting is going super
# progress is to goodtesting is going super
# progress is to good/ntesting is going super
# progress is to good

# %%
file = open('example.txt','w')
file.write('testing is going super\n')
file.write('progress is to good\n')
file.close()

# %%
file = open('example.txt','r')
print(file.read())
file.close()
# Out:
# testing is going super
# progress is to good

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import os
os.remove('example.txt')

# %%
file = open("good.txt","w")
file.write("hi all")
file.write("how r u")
file.write("bye")
file.close()

# %%
file = open("good.txt","r")
content = file.read()
print(content)
file.close()
# Out:
# hi allhow r ubye

# %%
file = open("good.txt","w")
file.write("hi all \n")
file.write("how r u \n")
file.write("bye")
file.close()

# %%
file = open("good.txt","r")
content = file.read()
print(content)
file.close()
# Out:
# hi all
# how r u
# bye

# %%
name = ["gowtham","mangayakarasi","rajesh","sudhanshu","kumar"]

# %%
for i in name:
  print(i)
  if i == "rajesh":
    break
# Out:
# gowtham
# mangayakarasi
# rajesh

# %%
f = open("name.txt","w")
for i in name:
  f.write(i)
  f.write("\n")
  if i == "rajesh":
    break

f.close()

# %%
f = open("name.txt","r")
content = f.read()
print(content)
f.close()
# Out:
# gowtham
# mangayakarasi
# rajesh

# %%
f=open("myfile.txt","w")
for i in name:
    f.write(i)
    if i=="rajesh":
        break
    f.write("\n")
f.close()

# %%
f = open("myfile.txt","r")
content = f.read()
print(content)
f.close()
# Out:
# gowtham
# mangayakarasi
# rajesh

# %%
emp={"gowtham":26,"mangayakarasi":25,"rajesh":24,"sudhanshu":63,"kumar":22}
# task3 get the name of the employee in file  whose age is >= 25
emp_name = open("emp.txt","w")

for i,j in emp.items():
  if j>=25:
    emp_name.write(i)
    emp_name.write("\n")

emp_name.close()

# %%
a = open("emp.txt","r")
content = a.read()
print(content)
a.close()
# Out:
# gowtham
# mangayakarasi
# sudhanshu

# %%
e = {"e1":{"name":"gowtham","age":26,"city":"chennai","salary":45000},
       "e2":{"name":"mangayakarasi","age":25,"city":"madurai","salary":95000},
       "e3":{"name":"rajesh","age":24,"city":"chennai","salary":85000},
       "e4":{"name":"sudhanshu","age":63,"city":"chennai","salary":65000},
       "e5":{"name":"kumar","age":22,"city":"madurai","salary":55000}}

# %%
print(e)
# Out:
# {'e1': {'name': 'gowtham', 'age': 26, 'city': 'chennai', 'salary': 45000}, 'e2': {'name': 'mangayakarasi', 'age': 25, 'city': 'madurai', 'salary': 95000}, 'e3': {'name': 'rajesh', 'age': 24, 'city': 'chennai', 'salary': 85000}, 'e4': {'name': 'sudhanshu', 'age': 63, 'city': 'chennai', 'salary': 65000}, 'e5': {'name': 'kumar', 'age': 22, 'city': 'madurai', 'salary': 55000}}

# %%
c=[]
m=[]
for i in e:
    for j in e[i]:
        if e[i][j]=="chennai":
            c.append(e[i]["salary"])
        if e[i][j]=="madurai":
            m.append(e[i]["salary"])
chennai=int(sum(c)/len(c))
madurai=int(sum(m)/len(m))
salary_city=open("salary_city.txt","w")
salary_city.write("The average salary in chennai is\t")
salary_city.write(str(chennai))
salary_city.write("\nThe average salary in madurai is\t")
salary_city.write(str(madurai))
salary_city.close()

# %%
a = open("salary_city.txt","r")
print(a.read())
a.close()
# Out:
# The average salary in chennai is	65000
# The average salary in madurai is	75000

# %% [markdown]
# #**OOPS:Object Oriented Programming**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# class - template , blueprint -> constructor for object
# object - instance of a class
# method - function inside a class
# class variable , attribute , property - variable inside a class

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class hdfc: #2
    bankname = "HDFC" #3 creates property a.bankname = "HDFC"
    name = "rajesh" #4 creates property a.name = "rajesh"
    age = 23 #5 creates property a.age = 23
    place= "madurai" #6 creates property a.place = "madurai"

# %%
a = hdfc() #1 creates obj based on class hdfc #7

#note:  if we equalate any class to a variable then it will be an object

# %%
print(type(a))
# Out:
# <class '__main__.hdfc'>

# %%
a

# %%
# print the values of object
#syntax: object_name.atribute_name
a.bankname,a.name,a.age,a.place
# Out:
# ('HDFC', 'rajesh', 23, 'madurai')

# %%
b = hdfc()

# %%
b,b.place,b.bankname,b.age,b.name
# Out:
# (<__main__.hdfc at 0x7ee9eed4a170>, 'madurai', 'HDFC', 23, 'rajesh')

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Modify Object Properties
# You can modify properties on objects like this:

a.name = "vigneshwar"

# %%
a.bankname,a.name,a.age,a.place
# Out:
# ('HDFC', 'vigneshwar', 23, 'madurai')

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Basic Initialization
class Person:
    def __init__(self, name, age):  # Constructor
        self.name = name  # Attribute initialization
        self.age = age

# Creating an object
person1 = Person("Vigneshwar", 16)

# Accessing attributes
print(person1.name)  # Output: Vigneshwar
print(person1.age)   # Output: 16
# Out:
# Vigneshwar
# 16

# %%
# Default Values
# You can set default values for parameters in the __init__() function.
class Person:
    def __init__(self, name="Unknown", age=0):
        self.name = name
        self.age = age

# Creating objects with and without parameters
person1 = Person("Vigneshwar", 16)
person2 = Person()

print(person1.name, person1.age)  # Output: Vigneshwar 16
print(person2.name, person2.age)  # Output: Unknown 0
# Out:
# Vigneshwar 16
# Unknown 0

# %%
# if you want give a default value for any attribute look at step 7. this is one of the methode.
class emp: #2
    def __init__(self,emp_name,emp_age,emp_city): #3 self = e1, emp_name = "rajesh", emp_age = 23, emp_city = "madurai"
        self.name = emp_name #4 e1.name = "rajesh"
        self.age = emp_age #5 e1.age = 23
        self.city = emp_city #6 e1.city = "madurai"
    salary=45000 #7

# %%
e1 = emp("rajesh",23,"madurai") #1 creates obj based on class emp

# %%
print(e1,e1.name,e1.age,e1.city,e1.salary)
# Out:
# <__main__.emp object at 0x7ee9eea9ae00> rajesh 23 madurai 45000

# %%
e2 = emp("baby",24,"chennai")
e2 , e2.salary, e2.name , e2.age , e2.city
# Out:
# (<__main__.emp at 0x7ee9eea99780>, 45000, 'baby', 24, 'chennai')

# %%
# Using __init__() with Methods
# The __init__() method can also work in conjunction with other methods to make the class functional.

class BankAccount:
    def __init__(self, account_holder, balance=0):
        self.account_holder = account_holder
        self.balance = balance

    def deposit(self, amount):
        self.balance += amount
        print(f"{amount} deposited. New balance: {self.balance}")

    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance -= amount
            print(f"{amount} withdrawn. Remaining balance: {self.balance}")
        else:
            print("Insufficient balance!")

# Creating an object
account = BankAccount("Vigneshwar", 1000)

# Using methods
account.deposit(500)  # Output: 500 deposited. New balance: 1500
account.withdraw(200) # Output: 200 withdrawn. Remaining balance: 1300
# Out:
# 500 deposited. New balance: 1500
# 200 withdrawn. Remaining balance: 1300

# %%
account2 = BankAccount("akaash")

# %%
account2.withdraw(200)
# Out:
# Insufficient balance!

# %%
class trans:
    def __init__(self,from1 , to , amount,via):
        self.from1 = from1
        self.to = to
        self.amount = amount
        self.via = via
    def show(self): #2
        print("Hi", self.from1 ,"sent" , self.amount , "to", self.to , "via", self.via)

# %%
t1 = trans("shabari","selva",4000,"gpay")

# %%
t1,t1.from1,t1.to,t1.amount,t1.via
# Out:
# (<__main__.trans at 0x7ee9ee990e80>, 'shabari', 'selva', 4000, 'gpay')

# %%
t2 = trans("hemanth","tamil",9500,"paytm")
t2,t2.from1,t2.to,t2.amount,t2.via
# Out:
# (<__main__.trans at 0x7ee9ee990580>, 'hemanth', 'tamil', 9500, 'paytm')

# %%
t1.show()
t2.show()
# Out:
# Hi shabari sent 4000 to selva via gpay
# Hi hemanth sent 9500 to tamil via paytm

# %%
class emp:
    def __init__(self,emp_name,emp_age,cert,personal_info):
        self.name = emp_name
        self.age = emp_age
        self.certificate = cert
        self.personal = personal_info
    def show(self):
        print(self.name,self.age,self.certificate,self.personal)

# %%
# here we gave value of list to one attribute and values of dict to another attribute
e1 = emp("rajesh",23,["aws ","devops"],{"city":"madurai","salary":45000})

# %%
e1.show()
# Out:
# rajesh 23 ['aws ', 'devops'] {'city': 'madurai', 'salary': 45000}

# %%
class emp:
    def __init__(self,emp_name,emp_age,cert,personal_info):
        self.name = emp_name
        self.age = emp_age
        self.certificate = cert
        self.personal = personal_info
    def show(self):
        print("firstname",self.firstname,"secondname",self.lastname,"age",self.age,"cert",self.certificate,"personal",self.personal)
    def modify(self):
        self.firstname , self.lastname = self.name.split()

# %%
e1 = emp("rajesh kumar",23,["aws ","devops"],{"city":"madurai","salary":45000})

# %%
e1.modify()
e1.show()
# Out:
# firstname rajesh secondname kumar age 23 cert ['aws ', 'devops'] personal {'city': 'madurai', 'salary': 45000}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Person:
  def __init__(self, name, age):
    self.name = name
    self.age = age

    def __str__(self):
      return f"{self.name}({self.age})"

p1 = Person("John", 36)

print(p1.name,p1.age)
# Out:
# John 36

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
del p1.age

# %%
print(p1.age) # error occurs because we delete thw attribute age.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-9506c9e80e91> in <cell line: 1>()
# ----> 1 print(p1.age)
#
# AttributeError: 'Person' object has no attribute 'age'

# %%
del p1

# %%
print(p1) # error occurs because i have deleted the object p1.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-71a0f0e933fe> in <cell line: 1>()
# ----> 1 print(p1)
#
# NameError: name 'p1' is not defined

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class emp:
    def __init__(self,id,emp_name,emp_age,cert,personal_info):
        self.id=id
        self.name = emp_name
        self.age = emp_age
        self.certificate = cert
        self.personal = personal_info
    def show(self):
        print("id",self.id, "\nfirstname",self.firstname,"\tsecondname",self.lastname,"\nage",self.age,"\ncert",self.certificate,"\npersonal",self.personal)
    def modify(self):
        self.firstname , self.lastname = self.name.split()

class guvi(emp):
    pass

# %%
e1 = guvi(100,"rajesh kumar",23,["aws ","devops"],{"city":"madurai","salary":45000})

# %%
e1.modify()
e1.show()
# Out:
# id 100
# firstname rajesh 	secondname kumar
# age 23
# cert ['aws ', 'devops']
# personal {'city': 'madurai', 'salary': 45000}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Person:
  def __init__(self, fname, lname):
    self.firstname = fname
    self.lastname = lname

  def printname(self):
    print(self.firstname, self.lastname)

#Use the Person class to create an object, and then execute the printname method:

x = Person("John", "Doe")
x.printname()
# Out:
# John Doe

# %%
class student(Person):
  def __init__(self,fname,lname):
    Person.__init__(self,fname,lname)

# %%
y = student("saran","sharma")
y.printname()
# Out:
# saran sharma

# %%
class emp:
    def __init__(self,id,emp_name,emp_age,cert,personal_info):
        self.id=id
        self.name = emp_name
        self.age = emp_age
        self.certificate = cert
        self.personal = personal_info
    def show(self):
        print("id",self.id, "\nfirstname",self.firstname,"\tsecondname",self.lastname,"\nage",self.age,"\ncert",self.certificate,"\npersonal",self.personal)
    def modify(self):
        self.firstname , self.lastname = self.name.split()

class guvi(emp):
    def show(self):
        print("id","G"+str(self.id), "\nfirstname",self.firstname,"\tsecondname",self.lastname,"\nage",self.age,"\ncert",self.certificate,"\npersonal",self.personal)

# %%
e1 = guvi(100,"rajesh kumar",23,["aws ","devops"],{"city":"madurai","salary":45000})

# %%
e1.modify()
e1.show()
# Out:
# id G100
# firstname rajesh 	secondname kumar
# age 23
# cert ['aws ', 'devops']
# personal {'city': 'madurai', 'salary': 45000}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class student(Person):
  def __init__(self,fname,lname):
    super().__init__(fname,lname)

# %%
z = student("rohit","sharma")
z.printname()
# Out:
# rohit sharma

# %%
#Add Properties
#Add a property called graduationyear to the Student class

class Student(Person):
  def __init__(self, fname, lname):
    super().__init__(fname, lname)
    self.graduationyear = 2019

# %%
z = student("rohit","sharma")
z.printname()
# Out:
# rohit sharma
